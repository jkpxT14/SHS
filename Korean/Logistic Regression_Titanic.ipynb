# %% [markdown]
# ## <수능특강 - Binary Classification - Logistic Regression - Titanic>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
passengers=sns.load_dataset("titanic")

print(passengers)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
passengers["sex"]=passengers["sex"].map({"female": 1, "male": 0})

print(passengers)
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    0  22.0      1      0   7.2500        S   Third
# 1           1       1    1  38.0      1      0  71.2833        C   First
# 2           1       3    1  26.0      0      0   7.9250        S   Third
# 3           1       1    1  35.0      1      0  53.1000        S   First
# 4           0       3    0  35.0      0      0   8.0500        S   Third
# ..        ...     ...  ...   ...    ...    ...      ...      ...     ...
# 886         0       2    0  27.0      0      0  13.0000        S  Second
# 887         1       1    1  19.0      0      0  30.0000        S   First
# 888         0       3    1   NaN      1      2  23.4500        S   Third
# 889         1       1    0  26.0      0      0  30.0000        C   First
# 890         0       3    0  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
passengers["age"]=passengers["age"].fillna(value=passengers["age"].mean())

print(passengers)
# Out:
#      survived  pclass  sex        age  sibsp  parch     fare embarked   class  \
# 0           0       3    0  22.000000      1      0   7.2500        S   Third
# 1           1       1    1  38.000000      1      0  71.2833        C   First
# 2           1       3    1  26.000000      0      0   7.9250        S   Third
# 3           1       1    1  35.000000      1      0  53.1000        S   First
# 4           0       3    0  35.000000      0      0   8.0500        S   Third
# ..        ...     ...  ...        ...    ...    ...      ...      ...     ...
# 886         0       2    0  27.000000      0      0  13.0000        S  Second
# 887         1       1    1  19.000000      0      0  30.0000        S   First
# 888         0       3    1  29.699118      1      2  23.4500        S   Third
# 889         1       1    0  26.000000      0      0  30.0000        C   First
# 890         0       3    0  32.000000      0      0   7.7500        Q   Third
#
# ...

# %%
passengers["FirstClass"]=passengers["pclass"].apply(lambda x: 1 if x==1 else 0)
passengers["SecondClass"]=passengers["pclass"].apply(lambda x: 1 if x==2 else 0)

print(passengers)
# Out:
#      survived  pclass  sex        age  sibsp  parch     fare embarked   class  \
# 0           0       3    0  22.000000      1      0   7.2500        S   Third
# 1           1       1    1  38.000000      1      0  71.2833        C   First
# 2           1       3    1  26.000000      0      0   7.9250        S   Third
# 3           1       1    1  35.000000      1      0  53.1000        S   First
# 4           0       3    0  35.000000      0      0   8.0500        S   Third
# ..        ...     ...  ...        ...    ...    ...      ...      ...     ...
# 886         0       2    0  27.000000      0      0  13.0000        S  Second
# 887         1       1    1  19.000000      0      0  30.0000        S   First
# 888         0       3    1  29.699118      1      2  23.4500        S   Third
# 889         1       1    0  26.000000      0      0  30.0000        C   First
# 890         0       3    0  32.000000      0      0   7.7500        Q   Third
#
# ...

# %%
features=passengers[["sex", "age", "FirstClass", "SecondClass"]]

print(features)
# Out:
#      sex        age  FirstClass  SecondClass
# 0      0  22.000000           0            0
# 1      1  38.000000           1            0
# 2      1  26.000000           0            0
# 3      1  35.000000           1            0
# 4      0  35.000000           0            0
# ..   ...        ...         ...          ...
# 886    0  27.000000           0            1
# 887    1  19.000000           1            0
# 888    1  29.699118           0            0
# 889    0  26.000000           1            0
# 890    0  32.000000           0            0
#
# [891 rows x 4 columns]

# %%
survival=passengers["survived"]

print(survival)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
train_features, test_features, train_labels, test_labels = train_test_split(features, survival)

# %%
# [Study] Normalization?
scaler=StandardScaler()
train_features=scaler.fit_transform(train_features)
test_features=scaler.fit_transform(test_features)

# %%
model=LogisticRegression()
model.fit(train_features, train_labels)
# Out:
# LogisticRegression()

# %%
print(model.score(train_features, train_labels))
# Out:
# 0.7739520958083832

# %%
print(model.score(test_features, test_labels))
# Out:
# 0.8161434977578476

# %%
print(model.coef_)
# Out:
# [[ 1.14603729 -0.37029509  0.98465888  0.52798779]]

# %%
Jake=np.array([0.0, 18.0, 0.0, 0.0])
Seol=np.array([0.0, 18.0, 1.0, 0.0])
sample_passengers=np.array([Jake, Seol])
sample_passengers=scaler.transform(sample_passengers)
print(model.predict(sample_passengers))
print(model.predict_proba(sample_passengers))
# Out:
# [0 1]
# [[0.85835008 0.14164992]
#  [0.36371548 0.63628452]]
# c:\Users\jkpxtwin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
